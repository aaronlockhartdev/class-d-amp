# %%
import lcapy
from lcapy import s

# %%
ckt = lcapy.Circuit('../sym_analysis/lcapy/class_d_bp.sch')
ckt.draw()

# %%
tf = ckt.out.V(s)
# Out:
# Using symengine
# Done solving
# Finished matrix solve
# {'s': s, 't': t, 'f_0': f_0, 'f': f, 'omega': omega, 'omega_0': omega_0, 'tau': tau, 'nu': nu, 'Omega': Omega, 'F': F, 'n': n, 'k': k, 'z': z, 'Delta_t': Delta_t, 'Delta_f': Delta_f, 'epsilon42': epsilon42, 'I': I, 'Vs': Vs, 'Lfilt': Lfilt, 'Cfilt': Cfilt, 'Rfb': Rfb, 'Rin': Rin, 'Cf1': Cf1, 'Rf': Rf, 'Cf2': Cf2, 'Ranon1': Ranon1, 'Cl1': Cl1, 'Cl2': Cl2, 'Cl3': Cl3, 'Cl4': Cl4, 'Rl1': Rl1, 'Rl2': Rl2, 'Rlg1': Rlg1, 'Rlg2': Rlg2, 'Rlg3': Rlg3, 'Rlbp': Rlbp, 'Ranon7': Ranon7, 'Ci': Ci, 'Ri2': Ri2, 'Ri1': Ri1, 'Ranon11': Ranon11, 'Ranon17': Ranon17, 'Ranon18': Ranon18, 'A': A}
# /Users/aaron/projects/lcapy/lcapy/netlist.py:456: SyntaxWarning: invalid escape sequence '\,'
#   """Create a new netlist with the node voltages annotated.  This is
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ...
